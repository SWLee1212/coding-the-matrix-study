# %%
"""

from vec import Vec

------- For getitem(v,d):

Return the value of entry d in v.
Be sure getitem(v,d) returns 0 if d is not represented in v.f.

>>> v = Vec({'a','b','c', 'd'},{'a':2,'c':1,'d':3})
>>> v['d']
3
>>> v['b']
0

------- For setitem(v,d,val):

Set the element of v with label d to be val.
setitem(v,d,val) should set the value for key d even if d
  is not previously represented in v.f.

>>> v = Vec({'a', 'b', 'c'}, {'b':0})
>>> v['b'] = 5
>>> v['b']
5
>>> v['a'] = 1
>>> v['a']
1

------- For equal(u,v):

Return true iff u is equal to v.
Because of sparse representation, it is not enough to compare dictionaries

>>> Vec({'a', 'b', 'c'}, {'a':0}) == Vec({'a', 'b', 'c'}, {'b':0})
True

Be sure that equal(u, v) check equalities for all keys from u.f and v.f even if some keys in u.f do not exist in v.f (or vice versa)

>>> Vec({'x','y','z'},{'y':1,'x':2}) == Vec({'x','y','z'},{'y':1,'z':0})
False
>>> Vec({'a','b','c'}, {'a':0,'c':1}) == Vec({'a','b','c'}, {'a':0,'c':1,'b':4})
False
>>> Vec({'a','b','c'}, {'a':0,'c':1,'b':4}) == Vec({'a','b','c'}, {'a':0,'c':1})
False

The keys matter:
>>> Vec({'a','b'},{'a':1}) == Vec({'a','b'},{'b':1})
False

The values matter:
>>> Vec({'a','b'},{'a':1}) == Vec({'a','b'},{'a':2})
False

------- For add(u, v):

Returns the sum of the two vectors.
Be sure to add together values for all keys from u.f and v.f even if some keys in u.f do not exist in v.f (or vice versa)

>>> a = Vec({'a','e','i','o','u'}, {'a':0,'e':1,'i':2})
>>> b = Vec({'a','e','i','o','u'}, {'o':4,'u':7})
>>> c = Vec({'a','e','i','o','u'}, {'a':0,'e':1,'i':2,'o':4,'u':7})
>>> a + b == c
True
>>> d = Vec({'x','y','z'}, {'x':2,'y':1})
>>> e = Vec({'x','y','z'}, {'z':4,'y':-1})
>>> f = Vec({'x','y','z'}, {'x':2,'y':0,'z':4})
>>> d + e == f
True
>>> b + Vec({'a','e','i','o','u'}, {}) == b
True

------- For dot(u, v):

Returns the dot product of the two vectors.

>>> u1 = Vec({'a','b'}, {'a':1, 'b':2})
>>> u2 = Vec({'a','b'}, {'b':2, 'a':1})
>>> u1*u2
5
>>> v1 = Vec({'p','q','r','s'}, {'p':2,'s':3,'q':-1,'r':0})
>>> v2 = Vec({'p','q','r','s'}, {'p':-2,'r':5})
>>> v1*v2
-4
>>> w1 = Vec({'a','b','c'}, {'a':2,'b':3,'c':4})
>>> w2 = Vec({'a','b','c'}, {'a':12,'b':8,'c':6})
>>> w1*w2
72

The pairwise products should not be collected in a set before summing
because a set eliminates duplicates
>>> v1 = Vec({1, 2}, {1 : 3, 2 : 6})
>>> v2 = Vec({1, 2}, {1 : 2, 2 : 1})
>>> v1 * v2
12

------- For scalar_mul(v, alpha):

Returns the scalar-vector product alpha times v.

>>> zero = Vec({'x','y','z','w'}, {})
>>> u = Vec({'x','y','z','w'},{'x':1,'y':2,'z':3,'w':4})
>>> 0*u == zero
True
>>> 1*u == u
True
>>> 0.5*u == Vec({'x','y','z','w'},{'x':0.5,'y':1,'z':1.5,'w':2})
True

------- For neg(v):

Returns the negation of vector v. Be sure that all values in v.f are negated
>>> zero = Vec({'x','y','z'}, {})
>>> -zero == zero
True
>>> v = Vec({0,1,2,3,4,'a'}, {0:1,1:-1,2:-1,3:1})
>>> -v == Vec({0,1,2,3,4,'a'}, {0:-1,1:1,2:1,3:-1})
True
>>> -(-v) == v
True
>>> v == -v
False

"""

if __name__ == "__main__":
    import doctest
    doctest.testmod()
# Out:
# **********************************************************************
# File "__main__", line 11, in __main__
# Failed example:
#     v = Vec({'a','b','c', 'd'},{'a':2,'c':1,'d':3})
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\ProgramData\Miniconda3\envs\my_or\lib\doctest.py", line 1321, in __run
#         compileflags, 1), test.globs)
#       File "<doctest __main__[0]>", line 1, in <module>
#         v = Vec({'a','b','c', 'd'},{'a':2,'c':1,'d':3})
#     NameError: name 'Vec' is not defined
# **********************************************************************
# File "__main__", line 12, in __main__
# Failed example:
#     v['d']
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\ProgramData\Miniconda3\envs\my_or\lib\doctest.py", line 1321, in __run
#         compileflags, 1), test.globs)
#       File "<doctest __main__[1]>", line 1, in <module>
#         v['d']
#     NameError: name 'v' is not defined
# **********************************************************************
# File "__main__", line 14, in __main__
# Failed example:
#     v['b']
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\ProgramData\Miniconda3\envs\my_or\lib\doctest.py", line 1321, in __run
#         compileflags, 1), test.globs)
#       File "<doctest __main__[2]>", line 1, in <module>
#         v['b']
#     NameError: name 'v' is not defined
# **********************************************************************
# File "__main__", line 23, in __main__
# Failed example:
#     v = Vec({'a', 'b', 'c'}, {'b':0})
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\ProgramData\Miniconda3\envs\my_or\lib\doctest.py", line 1321, in __run
#         compileflags, 1), test.globs)
#       File "<doctest __main__[3]>", line 1, in <module>
#         v = Vec({'a', 'b', 'c'}, {'b':0})
#     NameError: name 'Vec' is not defined
# **********************************************************************
# File "__main__", line 24, in __main__
# Failed example:
#     v['b'] = 5
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\ProgramData\Miniconda3\envs\my_or\lib\doctest.py", line 1321, in __run
#         compileflags, 1), test.globs)
#       File "<doctest __main__[4]>", line 1, in <module>
#         v['b'] = 5
#     NameError: name 'v' is not defined
# **********************************************************************
# File "__main__", line 25, in __main__
# Failed example:
#     v['b']
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\ProgramData\Miniconda3\envs\my_or\lib\doctest.py", line 1321, in __run
#         compileflags, 1), test.globs)
#       File "<doctest __main__[5]>", line 1, in <module>
#         v['b']
#     NameError: name 'v' is not defined
# **********************************************************************
# File "__main__", line 27, in __main__
# Failed example:
#     v['a'] = 1
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\ProgramData\Miniconda3\envs\my_or\lib\doctest.py", line 1321, in __run
#         compileflags, 1), test.globs)
#       File "<doctest __main__[6]>", line 1, in <module>
#         v['a'] = 1
#     NameError: name 'v' is not defined
# **********************************************************************
# File "__main__", line 28, in __main__
# Failed example:
#     v['a']
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\ProgramData\Miniconda3\envs\my_or\lib\doctest.py", line 1321, in __run
#         compileflags, 1), test.globs)
#       File "<doctest __main__[7]>", line 1, in <module>
#         v['a']
#     NameError: name 'v' is not defined
# **********************************************************************
# File "__main__", line 36, in __main__
# Failed example:
#     Vec({'a', 'b', 'c'}, {'a':0}) == Vec({'a', 'b', 'c'}, {'b':0})
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\ProgramData\Miniconda3\envs\my_or\lib\doctest.py", line 1321, in __run
#         compileflags, 1), test.globs)
#       File "<doctest __main__[8]>", line 1, in <module>
#         Vec({'a', 'b', 'c'}, {'a':0}) == Vec({'a', 'b', 'c'}, {'b':0})
#     NameError: name 'Vec' is not defined
# **********************************************************************
# File "__main__", line 41, in __main__
# Failed example:
#     Vec({'x','y','z'},{'y':1,'x':2}) == Vec({'x','y','z'},{'y':1,'z':0})
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\ProgramData\Miniconda3\envs\my_or\lib\doctest.py", line 1321, in __run
#         compileflags, 1), test.globs)
#       File "<doctest __main__[9]>", line 1, in <module>
#         Vec({'x','y','z'},{'y':1,'x':2}) == Vec({'x','y','z'},{'y':1,'z':0})
#     NameError: name 'Vec' is not defined
# **********************************************************************
# File "__main__", line 43, in __main__
# Failed example:
#     Vec({'a','b','c'}, {'a':0,'c':1}) == Vec({'a','b','c'}, {'a':0,'c':1,'b':4})
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\ProgramData\Miniconda3\envs\my_or\lib\doctest.py", line 1321, in __run
#         compileflags, 1), test.globs)
#       File "<doctest __main__[10]>", line 1, in <module>
#         Vec({'a','b','c'}, {'a':0,'c':1}) == Vec({'a','b','c'}, {'a':0,'c':1,'b':4})
#     NameError: name 'Vec' is not defined
# **********************************************************************
# File "__main__", line 45, in __main__
# Failed example:
#     Vec({'a','b','c'}, {'a':0,'c':1,'b':4}) == Vec({'a','b','c'}, {'a':0,'c':1})
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\ProgramData\Miniconda3\envs\my_or\lib\doctest.py", line 1321, in __run
#         compileflags, 1), test.globs)
#       File "<doctest __main__[11]>", line 1, in <module>
#         Vec({'a','b','c'}, {'a':0,'c':1,'b':4}) == Vec({'a','b','c'}, {'a':0,'c':1})
#     NameError: name 'Vec' is not defined
# **********************************************************************
# File "__main__", line 49, in __main__
# Failed example:
#     Vec({'a','b'},{'a':1}) == Vec({'a','b'},{'b':1})
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\ProgramData\Miniconda3\envs\my_or\lib\doctest.py", line 1321, in __run
#         compileflags, 1), test.globs)
#       File "<doctest __main__[12]>", line 1, in <module>
#         Vec({'a','b'},{'a':1}) == Vec({'a','b'},{'b':1})
#     NameError: name 'Vec' is not defined
# **********************************************************************
# File "__main__", line 53, in __main__
# Failed example:
#     Vec({'a','b'},{'a':1}) == Vec({'a','b'},{'a':2})
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\ProgramData\Miniconda3\envs\my_or\lib\doctest.py", line 1321, in __run
#         compileflags, 1), test.globs)
#       File "<doctest __main__[13]>", line 1, in <module>
#         Vec({'a','b'},{'a':1}) == Vec({'a','b'},{'a':2})
#     NameError: name 'Vec' is not defined
# **********************************************************************
# File "__main__", line 61, in __main__
# Failed example:
#     a = Vec({'a','e','i','o','u'}, {'a':0,'e':1,'i':2})
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\ProgramData\Miniconda3\envs\my_or\lib\doctest.py", line 1321, in __run
#         compileflags, 1), test.globs)
#       File "<doctest __main__[14]>", line 1, in <module>
#         a = Vec({'a','e','i','o','u'}, {'a':0,'e':1,'i':2})
#     NameError: name 'Vec' is not defined
# **********************************************************************
# File "__main__", line 62, in __main__
# Failed example:
#     b = Vec({'a','e','i','o','u'}, {'o':4,'u':7})
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\ProgramData\Miniconda3\envs\my_or\lib\doctest.py", line 1321, in __run
#         compileflags, 1), test.globs)
#       File "<doctest __main__[15]>", line 1, in <module>
#         b = Vec({'a','e','i','o','u'}, {'o':4,'u':7})
#     NameError: name 'Vec' is not defined
# **********************************************************************
# File "__main__", line 63, in __main__
# Failed example:
#     c = Vec({'a','e','i','o','u'}, {'a':0,'e':1,'i':2,'o':4,'u':7})
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\ProgramData\Miniconda3\envs\my_or\lib\doctest.py", line 1321, in __run
#         compileflags, 1), test.globs)
#       File "<doctest __main__[16]>", line 1, in <module>
#         c = Vec({'a','e','i','o','u'}, {'a':0,'e':1,'i':2,'o':4,'u':7})
#     NameError: name 'Vec' is not defined
# **********************************************************************
# File "__main__", line 64, in __main__
# Failed example:
#     a + b == c
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\ProgramData\Miniconda3\envs\my_or\lib\doctest.py", line 1321, in __run
#         compileflags, 1), test.globs)
#       File "<doctest __main__[17]>", line 1, in <module>
#         a + b == c
#     NameError: name 'a' is not defined
# **********************************************************************
# File "__main__", line 66, in __main__
# Failed example:
#     d = Vec({'x','y','z'}, {'x':2,'y':1})
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\ProgramData\Miniconda3\envs\my_or\lib\doctest.py", line 1321, in __run
#         compileflags, 1), test.globs)
#       File "<doctest __main__[18]>", line 1, in <module>
#         d = Vec({'x','y','z'}, {'x':2,'y':1})
#     NameError: name 'Vec' is not defined
# **********************************************************************
# File "__main__", line 67, in __main__
# Failed example:
#     e = Vec({'x','y','z'}, {'z':4,'y':-1})
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\ProgramData\Miniconda3\envs\my_or\lib\doctest.py", line 1321, in __run
#         compileflags, 1), test.globs)
#       File "<doctest __main__[19]>", line 1, in <module>
#         e = Vec({'x','y','z'}, {'z':4,'y':-1})
#     NameError: name 'Vec' is not defined
# **********************************************************************
# File "__main__", line 68, in __main__
# Failed example:
#     f = Vec({'x','y','z'}, {'x':2,'y':0,'z':4})
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\ProgramData\Miniconda3\envs\my_or\lib\doctest.py", line 1321, in __run
#         compileflags, 1), test.globs)
#       File "<doctest __main__[20]>", line 1, in <module>
#         f = Vec({'x','y','z'}, {'x':2,'y':0,'z':4})
#     NameError: name 'Vec' is not defined
# **********************************************************************
# File "__main__", line 69, in __main__
# Failed example:
#     d + e == f
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\ProgramData\Miniconda3\envs\my_or\lib\doctest.py", line 1321, in __run
#         compileflags, 1), test.globs)
#       File "<doctest __main__[21]>", line 1, in <module>
#         d + e == f
#     NameError: name 'd' is not defined
# **********************************************************************
# File "__main__", line 71, in __main__
# Failed example:
#     b + Vec({'a','e','i','o','u'}, {}) == b
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\ProgramData\Miniconda3\envs\my_or\lib\doctest.py", line 1321, in __run
#         compileflags, 1), test.globs)
#       File "<doctest __main__[22]>", line 1, in <module>
#         b + Vec({'a','e','i','o','u'}, {}) == b
#     NameError: name 'b' is not defined
# **********************************************************************
# File "__main__", line 78, in __main__
# Failed example:
#     u1 = Vec({'a','b'}, {'a':1, 'b':2})
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\ProgramData\Miniconda3\envs\my_or\lib\doctest.py", line 1321, in __run
#         compileflags, 1), test.globs)
#       File "<doctest __main__[23]>", line 1, in <module>
#         u1 = Vec({'a','b'}, {'a':1, 'b':2})
#     NameError: name 'Vec' is not defined
# **********************************************************************
# File "__main__", line 79, in __main__
# Failed example:
#     u2 = Vec({'a','b'}, {'b':2, 'a':1})
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\ProgramData\Miniconda3\envs\my_or\lib\doctest.py", line 1321, in __run
#         compileflags, 1), test.globs)
#       File "<doctest __main__[24]>", line 1, in <module>
#         u2 = Vec({'a','b'}, {'b':2, 'a':1})
#     NameError: name 'Vec' is not defined
# **********************************************************************
# File "__main__", line 80, in __main__
# Failed example:
#     u1*u2
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\ProgramData\Miniconda3\envs\my_or\lib\doctest.py", line 1321, in __run
#         compileflags, 1), test.globs)
#       File "<doctest __main__[25]>", line 1, in <module>
#         u1*u2
#     NameError: name 'u1' is not defined
# **********************************************************************
# File "__main__", line 82, in __main__
# Failed example:
#     v1 = Vec({'p','q','r','s'}, {'p':2,'s':3,'q':-1,'r':0})
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\ProgramData\Miniconda3\envs\my_or\lib\doctest.py", line 1321, in __run
#         compileflags, 1), test.globs)
#       File "<doctest __main__[26]>", line 1, in <module>
#         v1 = Vec({'p','q','r','s'}, {'p':2,'s':3,'q':-1,'r':0})
#     NameError: name 'Vec' is not defined
# **********************************************************************
# File "__main__", line 83, in __main__
# Failed example:
#     v2 = Vec({'p','q','r','s'}, {'p':-2,'r':5})
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\ProgramData\Miniconda3\envs\my_or\lib\doctest.py", line 1321, in __run
#         compileflags, 1), test.globs)
#       File "<doctest __main__[27]>", line 1, in <module>
#         v2 = Vec({'p','q','r','s'}, {'p':-2,'r':5})
#     NameError: name 'Vec' is not defined
# **********************************************************************
# File "__main__", line 84, in __main__
# Failed example:
#     v1*v2
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\ProgramData\Miniconda3\envs\my_or\lib\doctest.py", line 1321, in __run
#         compileflags, 1), test.globs)
#       File "<doctest __main__[28]>", line 1, in <module>
#         v1*v2
#     NameError: name 'v1' is not defined
# **********************************************************************
# File "__main__", line 86, in __main__
# Failed example:
#     w1 = Vec({'a','b','c'}, {'a':2,'b':3,'c':4})
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\ProgramData\Miniconda3\envs\my_or\lib\doctest.py", line 1321, in __run
#         compileflags, 1), test.globs)
#       File "<doctest __main__[29]>", line 1, in <module>
#         w1 = Vec({'a','b','c'}, {'a':2,'b':3,'c':4})
#     NameError: name 'Vec' is not defined
# **********************************************************************
# File "__main__", line 87, in __main__
# Failed example:
#     w2 = Vec({'a','b','c'}, {'a':12,'b':8,'c':6})
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\ProgramData\Miniconda3\envs\my_or\lib\doctest.py", line 1321, in __run
#         compileflags, 1), test.globs)
#       File "<doctest __main__[30]>", line 1, in <module>
#         w2 = Vec({'a','b','c'}, {'a':12,'b':8,'c':6})
#     NameError: name 'Vec' is not defined
# **********************************************************************
# File "__main__", line 88, in __main__
# Failed example:
#     w1*w2
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\ProgramData\Miniconda3\envs\my_or\lib\doctest.py", line 1321, in __run
#         compileflags, 1), test.globs)
#       File "<doctest __main__[31]>", line 1, in <module>
#         w1*w2
#     NameError: name 'w1' is not defined
# **********************************************************************
# File "__main__", line 93, in __main__
# Failed example:
#     v1 = Vec({1, 2}, {1 : 3, 2 : 6})
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\ProgramData\Miniconda3\envs\my_or\lib\doctest.py", line 1321, in __run
#         compileflags, 1), test.globs)
#       File "<doctest __main__[32]>", line 1, in <module>
#         v1 = Vec({1, 2}, {1 : 3, 2 : 6})
#     NameError: name 'Vec' is not defined
# **********************************************************************
# File "__main__", line 94, in __main__
# Failed example:
#     v2 = Vec({1, 2}, {1 : 2, 2 : 1})
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\ProgramData\Miniconda3\envs\my_or\lib\doctest.py", line 1321, in __run
#         compileflags, 1), test.globs)
#       File "<doctest __main__[33]>", line 1, in <module>
#         v2 = Vec({1, 2}, {1 : 2, 2 : 1})
#     NameError: name 'Vec' is not defined
# **********************************************************************
# File "__main__", line 95, in __main__
# Failed example:
#     v1 * v2
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\ProgramData\Miniconda3\envs\my_or\lib\doctest.py", line 1321, in __run
#         compileflags, 1), test.globs)
#       File "<doctest __main__[34]>", line 1, in <module>
#         v1 * v2
#     NameError: name 'v1' is not defined
# **********************************************************************
# File "__main__", line 102, in __main__
# Failed example:
#     zero = Vec({'x','y','z','w'}, {})
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\ProgramData\Miniconda3\envs\my_or\lib\doctest.py", line 1321, in __run
#         compileflags, 1), test.globs)
#       File "<doctest __main__[35]>", line 1, in <module>
#         zero = Vec({'x','y','z','w'}, {})
#     NameError: name 'Vec' is not defined
# **********************************************************************
# File "__main__", line 103, in __main__
# Failed example:
#     u = Vec({'x','y','z','w'},{'x':1,'y':2,'z':3,'w':4})
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\ProgramData\Miniconda3\envs\my_or\lib\doctest.py", line 1321, in __run
#         compileflags, 1), test.globs)
#       File "<doctest __main__[36]>", line 1, in <module>
#         u = Vec({'x','y','z','w'},{'x':1,'y':2,'z':3,'w':4})
#     NameError: name 'Vec' is not defined
# **********************************************************************
# File "__main__", line 104, in __main__
# Failed example:
#     0*u == zero
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\ProgramData\Miniconda3\envs\my_or\lib\doctest.py", line 1321, in __run
#         compileflags, 1), test.globs)
#       File "<doctest __main__[37]>", line 1, in <module>
#         0*u == zero
#     NameError: name 'u' is not defined
# **********************************************************************
# File "__main__", line 106, in __main__
# Failed example:
#     1*u == u
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\ProgramData\Miniconda3\envs\my_or\lib\doctest.py", line 1321, in __run
#         compileflags, 1), test.globs)
#       File "<doctest __main__[38]>", line 1, in <module>
#         1*u == u
#     NameError: name 'u' is not defined
# **********************************************************************
# File "__main__", line 108, in __main__
# Failed example:
#     0.5*u == Vec({'x','y','z','w'},{'x':0.5,'y':1,'z':1.5,'w':2})
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\ProgramData\Miniconda3\envs\my_or\lib\doctest.py", line 1321, in __run
#         compileflags, 1), test.globs)
#       File "<doctest __main__[39]>", line 1, in <module>
#         0.5*u == Vec({'x','y','z','w'},{'x':0.5,'y':1,'z':1.5,'w':2})
#     NameError: name 'u' is not defined
# **********************************************************************
# File "__main__", line 114, in __main__
# Failed example:
#     zero = Vec({'x','y','z'}, {})
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\ProgramData\Miniconda3\envs\my_or\lib\doctest.py", line 1321, in __run
#         compileflags, 1), test.globs)
#       File "<doctest __main__[40]>", line 1, in <module>
#         zero = Vec({'x','y','z'}, {})
#     NameError: name 'Vec' is not defined
# **********************************************************************
# File "__main__", line 115, in __main__
# Failed example:
#     -zero == zero
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\ProgramData\Miniconda3\envs\my_or\lib\doctest.py", line 1321, in __run
#         compileflags, 1), test.globs)
#       File "<doctest __main__[41]>", line 1, in <module>
#         -zero == zero
#     NameError: name 'zero' is not defined
# **********************************************************************
# File "__main__", line 117, in __main__
# Failed example:
#     v = Vec({0,1,2,3,4,'a'}, {0:1,1:-1,2:-1,3:1})
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\ProgramData\Miniconda3\envs\my_or\lib\doctest.py", line 1321, in __run
#         compileflags, 1), test.globs)
#       File "<doctest __main__[42]>", line 1, in <module>
#         v = Vec({0,1,2,3,4,'a'}, {0:1,1:-1,2:-1,3:1})
#     NameError: name 'Vec' is not defined
# **********************************************************************
# File "__main__", line 118, in __main__
# Failed example:
#     -v == Vec({0,1,2,3,4,'a'}, {0:-1,1:1,2:1,3:-1})
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\ProgramData\Miniconda3\envs\my_or\lib\doctest.py", line 1321, in __run
#         compileflags, 1), test.globs)
#       File "<doctest __main__[43]>", line 1, in <module>
#         -v == Vec({0,1,2,3,4,'a'}, {0:-1,1:1,2:1,3:-1})
#     NameError: name 'v' is not defined
# **********************************************************************
# File "__main__", line 120, in __main__
# Failed example:
#     -(-v) == v
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\ProgramData\Miniconda3\envs\my_or\lib\doctest.py", line 1321, in __run
#         compileflags, 1), test.globs)
#       File "<doctest __main__[44]>", line 1, in <module>
#         -(-v) == v
#     NameError: name 'v' is not defined
# **********************************************************************
# File "__main__", line 122, in __main__
# Failed example:
#     v == -v
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\ProgramData\Miniconda3\envs\my_or\lib\doctest.py", line 1321, in __run
#         compileflags, 1), test.globs)
#       File "<doctest __main__[45]>", line 1, in <module>
#         v == -v
#     NameError: name 'v' is not defined
# **********************************************************************
# 1 items had failures:
#   46 of  46 in __main__
# ***Test Failed*** 46 failures.
